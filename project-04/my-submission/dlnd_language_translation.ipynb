# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)
print(view_sentence_range[0], ' ', view_sentence_range[1])

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# 0   10
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    # prepare lists to return
    source_id_text = []
    target_id_text = []
    
    # convert source texts to word ids
    for sentence in source_text.split('\n'):
        id_text = [source_vocab_to_int[word] for word in sentence.split()]            
        source_id_text.append(id_text)
    
    # grab EOS id
    EOS_id = target_vocab_to_int['<EOS>']
    
    # convert target texts to word ids
    for sentence in target_text.split('\n'):
        id_text = [target_vocab_to_int[word] for word in sentence.split()]
        # add EOS to every end of target sentence
        id_text.append(EOS_id)
        target_id_text.append(id_text)
    
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    input_data = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    target_sequence_length = tf.placeholder(tf.int32, [None], name='target_sequence_length')
    max_target_len = tf.reduce_max(target_sequence_length, name='max_target_len')
    source_sequence_length = tf.placeholder(tf.int32, [None], name='source_sequence_length')
    
    return input_data, targets, learning_rate, keep_prob, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    GO_ID = target_vocab_to_int['<GO>']
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat( [tf.fill([batch_size, 1], GO_ID), ending], 1 )
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    # Embed the encoder
    enc_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)
    
    # Construct a stacked tf.contrib.rnn.LSTMCell wrapped in a tf.contrib.rnn.DropoutWrapper
    #enc_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.BasicLSTMCell(rnn_size), output_keep_prob=keep_prob) for _ in range(num_layers)], state_is_tuple=True )    
    def make_cell(rnn_size):
        enc_cell = tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2)))
        return enc_cell
    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    # Pass cell and embedded input to tf.nn.dynamic_rnn()
    enc_output, enc_state = tf.nn.dynamic_rnn(enc_cell, enc_embed_input, dtype=tf.float32)
    return enc_output, enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    # Create a tf.contrib.seq2seq.TrainingHelper
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input, 
                                                        sequence_length=target_sequence_length, 
                                                        time_major=False)
    # Create a tf.contrib.seq2seq.BasicDecoder
    # use dropout?
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, 
                                                       training_helper, 
                                                       encoder_state, 
                                                       output_layer)
    
    # Obtain the decoder outputs from tf.contrib.seq2seq.dynamic_decode
    train_dec_output, _ = tf.contrib.seq2seq.dynamic_decode(training_decoder, 
                                                            impute_finished=True, 
                                                            maximum_iterations=max_summary_length)

    return train_dec_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    # Create a tf.contrib.seq2seq.GreedyEmbeddingHelper
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
    greedy_embedding_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings, 
                                                                       start_tokens, 
                                                                       end_of_sequence_id)
    
    # Create a tf.contrib.seq2seq.BasicDecoder
    # use dropout?
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    infer_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, 
                                                    greedy_embedding_helper, 
                                                    encoder_state, 
                                                    output_layer)
    
    # Obtain the decoder outputs from tf.contrib.seq2seq.dynamic_decode
    infer_dec_output, _ = tf.contrib.seq2seq.dynamic_decode(infer_decoder, 
                                                            impute_finished=True, 
                                                            maximum_iterations=max_target_sequence_length)
    
    return infer_dec_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # prepare variables
    GO_ID = target_vocab_to_int['<GO>']
    EOS_ID = target_vocab_to_int['<EOS>']
    
    # Embed the target sequences, Construct the decoder LSTM cell
    #dec_embed_input = tf.contrib.layers.embed_sequence(dec_input, target_vocab_size, decoding_embedding_size)
    #dec_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.BasicLSTMCell(rnn_size), output_keep_prob=keep_prob) for _ in range(num_layers)], state_is_tuple=True )
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2)))
        return dec_cell
    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    # Output Layer
    #output_layer = lambda x: tf.contrib.layers.fully_connected(x, target_vocab_size, None, scope=decoding_scope)
    output_layer = Dense(target_vocab_size,
                         kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
        
    with tf.variable_scope("decoding") as decoding_scope:
        # Training Decoder
        train_logits = decoding_layer_train(encoder_state, 
                                            dec_cell, 
                                            dec_embed_input, 
                                            target_sequence_length, 
                                            max_target_sequence_length, 
                                            output_layer, 
                                            keep_prob)
    with tf.variable_scope("decoding", reuse=True) as decoding_scope:
        # Inference Decoder
        inference_logits = decoding_layer_infer(encoder_state, 
                                                dec_cell, 
                                                dec_embeddings, 
                                                GO_ID, 
                                                EOS_ID, 
                                                max_target_sequence_length, 
                                                target_vocab_size, 
                                                output_layer, 
                                                batch_size, 
                                                keep_prob)
    return train_logits, inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # Encode the input 
    enc_output, enc_state = encoding_layer(input_data, 
                                           rnn_size, 
                                           num_layers, 
                                           keep_prob, 
                                           source_sequence_length, 
                                           source_vocab_size, 
                                           enc_embedding_size)
    
    # Process target data
    dec_input = process_decoder_input(target_data, 
                                      target_vocab_to_int, 
                                      batch_size)
    
    # Decode the encoded input
    train_logits, inference_logits = decoding_layer(dec_input, 
                                                    enc_state,
                                                    target_sequence_length, 
                                                    max_target_sentence_length,
                                                    rnn_size, 
                                                    num_layers, 
                                                    target_vocab_to_int, 
                                                    target_vocab_size, 
                                                    batch_size, 
                                                    keep_prob, 
                                                    dec_embedding_size)
    return train_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 60
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 15
decoding_embedding_size = 15
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.5
display_step =
1077 - Train Accuracy: 0.8176, Validation Accuracy: 0.8288, Loss: 0.2655
# Epoch  22 Batch  200/1077 - Train Accuracy: 0.8156, Validation Accuracy: 0.8381, Loss: 0.2805
# Epoch  22 Batch  300/1077 - Train Accuracy: 0.8688, Validation Accuracy: 0.8267, Loss: 0.2419
# Epoch  22 Batch  400/1077 - Train Accuracy: 0.8594, Validation Accuracy: 0.8072, Loss: 0.2882
# Epoch  22 Batch  500/1077 - Train Accuracy: 0.8438, Validation Accuracy: 0.8366, Loss: 0.2362
# Epoch  22 Batch  600/1077 - Train Accuracy: 0.8356, Validation Accuracy: 0.8089, Loss: 0.2449
# Epoch  22 Batch  700/1077 - Train Accuracy: 0.8559, Validation Accuracy: 0.8335, Loss: 0.2417
# Epoch  22 Batch  800/1077 - Train Accuracy: 0.8469, Validation Accuracy: 0.8338, Loss: 0.2542
# Epoch  22 Batch  900/1077 - Train Accuracy: 0.8520, Validation Accuracy: 0.8200, Loss: 0.2647
# Epoch  22 Batch 1000/1077 - Train Accuracy: 0.8315, Validation Accuracy: 0.8278, Loss: 0.2269
# Epoch  23 Batch  100/1077 - Train Accuracy: 0.8500, Validation Accuracy: 0.8459, Loss: 0.2662
# Epoch  23 Batch  200/1077 - Train Accuracy: 0.8406, Validation Accuracy: 0.8203, Loss: 0.2616
# Epoch  23 Batch  300/1077 - Train Accuracy: 0.8873, Validation Accuracy: 0.8217, Loss: 0.2147
# Epoch  23 Batch  400/1077 - Train Accuracy: 0.8543, Validation Accuracy: 0.8324, Loss: 0.2860
# Epoch  23 Batch  500/1077 - Train Accuracy: 0.8488, Validation Accuracy: 0.8398, Loss: 0.2362
# Epoch  23 Batch  600/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8228, Loss: 0.2391
# Epoch  23 Batch  700/1077 - Train Accuracy: 0.8539, Validation Accuracy: 0.8178, Loss: 0.2314
# Epoch  23 Batch  800/1077 - Train Accuracy: 0.8469, Validation Accuracy: 0.8441, Loss: 0.2389
# Epoch  23 Batch  900/1077 - Train Accuracy: 0.8512, Validation Accuracy: 0.8228, Loss: 0.2775
# Epoch  23 Batch 1000/1077 - Train Accuracy: 0.8326, Validation Accuracy: 0.8079, Loss: 0.2241
# Epoch  24 Batch  100/1077 - Train Accuracy: 0.8371, Validation Accuracy: 0.8430, Loss: 0.2352
# Epoch  24 Batch  200/1077 - Train Accuracy: 0.8203, Validation Accuracy: 0.8370, Loss: 0.2676
# Epoch  24 Batch  300/1077 - Train Accuracy: 0.8861, Validation Accuracy: 0.8366, Loss: 0.2217
# Epoch  24 Batch  400/1077 - Train Accuracy: 0.8641, Validation Accuracy: 0.8082, Loss: 0.2654
# Epoch  24 Batch  500/1077 - Train Accuracy: 0.8449, Validation Accuracy: 0.8217, Loss: 0.2355
# Epoch  24 Batch  600/1077 - Train Accuracy: 0.8772, Validation Accuracy: 0.8374, Loss: 0.2319
# Epoch  24 Batch  700/1077 - Train Accuracy: 0.8559, Validation Accuracy: 0.8370, Loss: 0.2390
# Epoch  24 Batch  800/1077 - Train Accuracy: 0.8441, Validation Accuracy: 0.8327, Loss: 0.2400
# Epoch  24 Batch  900/1077 - Train Accuracy: 0.8609, Validation Accuracy: 0.8260, Loss: 0.2472
# Epoch  24 Batch 1000/1077 - Train Accuracy: 0.8586, Validation Accuracy: 0.8089, Loss: 0.2178
# Epoch  25 Batch  100/1077 - Train Accuracy: 0.8465, Validation Accuracy: 0.8381, Loss: 0.2340
# Epoch  25 Batch  200/1077 - Train Accuracy: 0.8395, Validation Accuracy: 0.8480, Loss: 0.2609
# Epoch  25 Batch  300/1077 - Train Accuracy: 0.9067, Validation Accuracy: 0.8285, Loss: 0.2076
# Epoch  25 Batch  400/1077 - Train Accuracy: 0.8730, Validation Accuracy: 0.8363, Loss: 0.2800
# Epoch  25 Batch  500/1077 - Train Accuracy: 0.8559, Validation Accuracy: 0.8381, Loss: 0.2348
# Epoch  25 Batch  600/1077 - Train Accuracy: 0.8783, Validation Accuracy: 0.8224, Loss: 0.2089
# Epoch  25 Batch  700/1077 - Train Accuracy: 0.8691, Validation Accuracy: 0.8366, Loss: 0.2268
# Epoch  25 Batch  800/1077 - Train Accuracy: 0.8516, Validation Accuracy: 0.8484, Loss: 0.2390
# Epoch  25 Batch  900/1077 - Train Accuracy: 0.8512, Validation Accuracy: 0.8288, Loss: 0.2337
# Epoch  25 Batch 1000/1077 - Train Accuracy: 0.8531, Validation Accuracy: 0.8480, Loss: 0.2119
# Epoch  26 Batch  100/1077 - Train Accuracy: 0.8594, Validation Accuracy: 0.8374, Loss: 0.2382
# Epoch  26 Batch  200/1077 - Train Accuracy: 0.8438, Validation Accuracy: 0.8484, Loss: 0.2451
# Epoch  26 Batch  300/1077 - Train Accuracy: 0.8972, Validation Accuracy: 0.8551, Loss: 0.2285
# Epoch  26 Batch  400/1077 - Train Accuracy: 0.8688, Validation Accuracy: 0.8516, Loss: 0.2683
# Epoch  26 Batch  500/1077 - Train Accuracy: 0.8672, Validation Accuracy: 0.8594, Loss: 0.2199
# Epoch  26 Batch  600/1077 - Train Accuracy: 0.8821, Validation Accuracy: 0.8509, Loss: 0.2131
# Epoch  26 Batch  700/1077 - Train Accuracy: 0.8773, Validation Accuracy: 0.8675, Loss: 0.2161
# Epoch  26 Batch  800/1077 - Train Accuracy: 0.8504, Validation Accuracy: 0.8516, Loss: 0.2310
# Epoch  26 Batch  900/1077 - Train Accuracy: 0.8805, Validation Accuracy: 0.8345, Loss: 0.2426
# Epoch  26 Batch 1000/1077 - Train Accuracy: 0.8560, Validation Accuracy: 0.8633, Loss: 0.2004
# Epoch  27 Batch  100/1077 - Train Accuracy: 0.8746, Validation Accuracy: 0.8569, Loss: 0.2324
# Epoch  27 Batch  200/1077 - Train Accuracy: 0.8523, Validation Accuracy: 0.8398, Loss: 0.2285
# Epoch  27 Batch  300/1077 - Train Accuracy: 0.9087, Validation Accuracy: 0.8643, Loss: 0.2099
# Epoch  27 Batch  400/1077 - Train Accuracy: 0.8680, Validation Accuracy: 0.8590, Loss: 0.2574
# Epoch  27 Batch  500/1077 - Train Accuracy: 0.8512, Validation Accuracy: 0.8697, Loss: 0.2026
# Epoch  27 Batch  600/1077 - Train Accuracy: 0.8735, Validation Accuracy: 0.8327, Loss: 0.2112
# Epoch  27 Batch  700/1077 - Train Accuracy: 0.8648, Validation Accuracy: 0.8619, Loss: 0.2102
# Epoch  27 Batch  800/1077 - Train Accuracy: 0.8590, Validation Accuracy: 0.8455, Loss: 0.2180
# Epoch  27 Batch  900/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.8331, Loss: 0.2229
# Epoch  27 Batch 1000/1077 - Train Accuracy: 0.8612, Validation Accuracy: 0.8516, Loss: 0.2025
# Epoch  28 Batch  100/1077 - Train Accuracy: 0.8941, Validation Accuracy: 0.8693, Loss: 0.2059
# Epoch  28 Batch  200/1077 - Train Accuracy: 0.8633, Validation Accuracy: 0.8693, Loss: 0.2193
# Epoch  28 Batch  300/1077 - Train Accuracy: 0.9005, Validation Accuracy: 0.8661, Loss: 0.1984
# Epoch  28 Batch  400/1077 - Train Accuracy: 0.8641, Validation Accuracy: 0.8572, Loss: 0.2383
# Epoch  28 Batch  500/1077 - Train Accuracy: 0.8770, Validation Accuracy: 0.8711, Loss: 0.2022
# Epoch  28 Batch  600/1077 - Train Accuracy: 0.8858, Validation Accuracy: 0.8551, Loss: 0.2022
# Epoch  28 Batch  700/1077 - Train Accuracy: 0.8762, Validation Accuracy: 0.8484, Loss: 0.1900
# Epoch  28 Batch  800/1077 - Train Accuracy: 0.8551, Validation Accuracy: 0.8612, Loss: 0.2181
# Epoch  28 Batch  900/1077 - Train Accuracy: 0.8926, Validation Accuracy: 0.8558, Loss: 0.2083
# Epoch  28 Batch 1000/1077 - Train Accuracy: 0.8754, Validation Accuracy: 0.8430, Loss: 0.1870
# Epoch  29 Batch  100/1077 - Train Accuracy: 0.9012, Validation Accuracy: 0.8651, Loss: 0.2005
# Epoch  29 Batch  200/1077 - Train Accuracy: 0.8508, Validation Accuracy: 0.8697, Loss: 0.2180
# Epoch  29 Batch  300/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8693, Loss: 0.1922
# Epoch  29 Batch  400/1077 - Train Accuracy: 0.8926, Validation Accuracy: 0.8565, Loss: 0.2236
# Epoch  29 Batch  500/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.8683, Loss: 0.1916
# Epoch  29 Batch  600/1077 - Train Accuracy: 0.8884, Validation Accuracy: 0.8544, Loss: 0.1927
# Epoch  29 Batch  700/1077 - Train Accuracy: 0.8746, Validation Accuracy: 0.8619, Loss: 0.1877
# Epoch  29 Batch  800/1077 - Train Accuracy: 0.8641, Validation Accuracy: 0.8469, Loss: 0.1974
# Epoch  29 Batch  900/1077 - Train Accuracy: 0.8820, Validation Accuracy: 0.8523, Loss: 0.2154
# Epoch  29 Batch 1000/1077 - Train Accuracy: 0.8739, Validation Accuracy: 0.8686, Loss: 0.2021
# Epoch  30 Batch  100/1077 - Train Accuracy: 0.8980, Validation Accuracy: 0.8572, Loss: 0.2122
# Epoch  30 Batch  200/1077 - Train Accuracy: 0.8766, Validation Accuracy: 0.8608, Loss: 0.2137
# Epoch  30 Batch  300/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.8636, Loss: 0.1808
# Epoch  30 Batch  400/1077 - Train Accuracy: 0.8941, Validation Accuracy: 0.8430, Loss: 0.2256
# Epoch  30 Batch  500/1077 - Train Accuracy: 0.8941, Validation Accuracy: 0.8750, Loss: 0.2021
# Epoch  30 Batch  600/1077 - Train Accuracy: 0.8817, Validation Accuracy: 0.8544, Loss: 0.1921
# Epoch  30 Batch  700/1077 - Train Accuracy: 0.9039, Validation Accuracy: 0.8679, Loss: 0.1710
# Epoch  30 Batch  800/1077 - Train Accuracy: 0.8766, Validation Accuracy: 0.8526, Loss: 0.1904
# Epoch  30 Batch  900/1077 - Train Accuracy: 0.8914, Validation Accuracy: 0.8548, Loss: 0.2140
# Epoch  30 Batch 1000/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.8629, Loss: 0.1937
# Epoch  31 Batch  100/1077 - Train Accuracy: 0.9020, Validation Accuracy: 0.8633, Loss: 0.2122
# Epoch  31 Batch  200/1077 - Train Accuracy: 0.8836, Validation Accuracy: 0.8565, Loss: 0.2063
# Epoch  31 Batch  300/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.8690, Loss: 0.1779
# Epoch  31 Batch  400/1077 - Train Accuracy: 0.9047, Validation Accuracy: 0.8864, Loss: 0.2125
# Epoch  31 Batch  500/1077 - Train Accuracy: 0.8836, Validation Accuracy: 0.8899, Loss: 0.1669
# Epoch  31 Batch  600/1077 - Train Accuracy: 0.9003, Validation Accuracy: 0.8679, Loss: 0.1710
# Epoch  31 Batch  700/1077 - Train Accuracy: 0.8754, Validation Accuracy: 0.8750, Loss: 0.1763
# Epoch  31 Batch  800/1077 - Train Accuracy: 0.8742, Validation Accuracy: 0.8665, Loss: 0.1898
# Epoch  31 Batch  900/1077 - Train Accuracy: 0.8926, Validation Accuracy: 0.8771, Loss: 0.2042
# Epoch  31 Batch 1000/1077 - Train Accuracy: 0.8791, Validation Accuracy: 0.8722, Loss: 0.1895
# Epoch  32 Batch  100/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.8729, Loss: 0.1845
# Epoch  32 Batch  200/1077 - Train Accuracy: 0.8973, Validation Accuracy: 0.8643, Loss: 0.1840
# Epoch  32 Batch  300/1077 - Train Accuracy: 0.9408, Validation Accuracy: 0.8775, Loss: 0.1625
# Epoch  32 Batch  400/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.8654, Loss: 0.2100
# Epoch  32 Batch  500/1077 - Train Accuracy: 0.8906, Validation Accuracy: 0.8707, Loss: 0.1768
# Epoch  32 Batch  600/1077 - Train Accuracy: 0.9025, Validation Accuracy: 0.8555, Loss: 0.1842
# Epoch  32 Batch  700/1077 - Train Accuracy: 0.8922, Validation Accuracy: 0.8722, Loss: 0.1792
# Epoch  32 Batch  800/1077 - Train Accuracy: 0.8727, Validation Accuracy: 0.8707, Loss: 0.1812
# Epoch  32 Batch  900/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.8796, Loss: 0.2018
# Epoch  32 Batch 1000/1077 - Train Accuracy: 0.8850, Validation Accuracy: 0.8651, Loss: 0.1738
# Epoch  33 Batch  100/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.8960, Loss: 0.1829
# Epoch  33 Batch  200/1077 - Train Accuracy: 0.8797, Validation Accuracy: 0.8782, Loss: 0.1907
# Epoch  33 Batch  300/1077 - Train Accuracy: 0.9515, Validation Accuracy: 0.8867, Loss: 0.1750
# Epoch  33 Batch  400/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8707, Loss: 0.2182
# Epoch  33 Batch  500/1077 - Train Accuracy: 0.9023, Validation Accuracy: 0.8754, Loss: 0.1758
# Epoch  33 Batch  600/1077 - Train Accuracy: 0.9204, Validation Accuracy: 0.8686, Loss: 0.1751
# Epoch  33 Batch  700/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.8853, Loss: 0.1781
# Epoch  33 Batch  800/1077 - Train Accuracy: 0.8918, Validation Accuracy: 0.8672, Loss: 0.1739
# Epoch  33 Batch  900/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.8800, Loss: 0.1984
# Epoch  33 Batch 1000/1077 - Train Accuracy: 0.8984, Validation Accuracy: 0.8778, Loss: 0.1745
# Epoch  34 Batch  100/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.8920, Loss: 0.1979
# Epoch  34 Batch  200/1077 - Train Accuracy: 0.8840, Validation Accuracy: 0.8778, Loss: 0.1815
# Epoch  34 Batch  300/1077 - Train Accuracy: 0.9511, Validation Accuracy: 0.8675, Loss: 0.1739
# Epoch  34 Batch  400/1077 - Train Accuracy: 0.9105, Validation Accuracy: 0.8878, Loss: 0.1926
# Epoch  34 Batch  500/1077 - Train Accuracy: 0.8973, Validation Accuracy: 0.8860, Loss: 0.1739
# Epoch  34 Batch  600/1077 - Train Accuracy: 0.9085, Validation Accuracy: 0.8743, Loss: 0.1732
# Epoch  34 Batch  700/1077 - Train Accuracy: 0.9102, Validation Accuracy: 0.8835, Loss: 0.1746
# Epoch  34 Batch  800/1077 - Train Accuracy: 0.8883, Validation Accuracy: 0.8775, Loss: 0.1871
# Epoch  34 Batch  900/1077 - Train Accuracy: 0.9102, Validation Accuracy: 0.8746, Loss: 0.1809
# Epoch  34 Batch 1000/1077 - Train Accuracy: 0.9167, Validation Accuracy: 0.8910, Loss: 0.1726
# Epoch  35 Batch  100/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.8981, Loss: 0.1744
# Epoch  35 Batch  200/1077 - Train Accuracy: 0.8887, Validation Accuracy: 0.8686, Loss: 0.1787
# Epoch  35 Batch  300/1077 - Train Accuracy: 0.9556, Validation Accuracy: 0.8714, Loss: 0.1543
# Epoch  35 Batch  400/1077 - Train Accuracy: 0.9043, Validation Accuracy: 0.8764, Loss: 0.2023
# Epoch  35 Batch  500/1077 - Train Accuracy: 0.9027, Validation Accuracy: 0.8700, Loss: 0.1653
# Epoch  35 Batch  600/1077 - Train Accuracy: 0.9115, Validation Accuracy: 0.8679, Loss: 0.1635
# Epoch  35 Batch  700/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.8878, Loss: 0.1642
# Epoch  35 Batch  800/1077 - Train Accuracy: 0.8895, Validation Accuracy: 0.8945, Loss: 0.1792
# Epoch  35 Batch  900/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.8896, Loss: 0.1692
# Epoch  35 Batch 1000/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8860, Loss: 0.1704
# Epoch  36 Batch  100/1077 - Train Accuracy: 0.8965, Validation Accuracy: 0.8931, Loss: 0.1747
# Epoch  36 Batch  200/1077 - Train Accuracy: 0.8945, Validation Accuracy: 0.8906, Loss: 0.1771
# Epoch  36 Batch  300/1077 - Train Accuracy: 0.9519, Validation Accuracy: 0.8970, Loss: 0.1633
# Epoch  36 Batch  400/1077 - Train Accuracy: 0.8938, Validation Accuracy: 0.8775, Loss: 0.1958
# Epoch  36 Batch  500/1077 - Train Accuracy: 0.9160, Validation Accuracy: 0.8771, Loss: 0.1653
# Epoch  36 Batch  600/1077 - Train Accuracy: 0.9189, Validation Accuracy: 0.8803, Loss: 0.1623
# Epoch  36 Batch  700/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8771, Loss: 0.1613
# Epoch  36 Batch  800/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8835, Loss: 0.1808
# Epoch  36 Batch  900/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.8949, Loss: 0.1681
# Epoch  36 Batch 1000/1077 - Train Accuracy: 0.8999, Validation Accuracy: 0.8746, Loss: 0.1600
# Epoch  37 Batch  100/1077 - Train Accuracy: 0.9223, Validation Accuracy: 0.8835, Loss: 0.1666
# Epoch  37 Batch  200/1077 - Train Accuracy: 0.8812, Validation Accuracy: 0.8888, Loss: 0.1697
# Epoch  37 Batch  300/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.8906, Loss: 0.1644
# Epoch  37 Batch  400/1077 - Train Accuracy: 0.9141, Validation Accuracy: 0.8743, Loss: 0.2013
# Epoch  37 Batch  500/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.9034, Loss: 0.1469
# Epoch  37 Batch  600/1077 - Train Accuracy: 0.9174, Validation Accuracy: 0.8857, Loss: 0.1595
# Epoch  37 Batch  700/1077 - Train Accuracy: 0.9176, Validation Accuracy: 0.8786, Loss: 0.1497
# Epoch  37 Batch  800/1077 - Train Accuracy: 0.9027, Validation Accuracy: 0.8686, Loss: 0.1641
# Epoch  37 Batch  900/1077 - Train Accuracy: 0.9121, Validation Accuracy: 0.8803, Loss: 0.1657
# Epoch  37 Batch 1000/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.8871, Loss: 0.1522
# Epoch  38 Batch  100/1077 - Train Accuracy: 0.9191, Validation Accuracy: 0.9002, Loss: 0.1677
# Epoch  38 Batch  200/1077 - Train Accuracy: 0.8887, Validation Accuracy: 0.8963, Loss: 0.1730
# Epoch  38 Batch  300/1077 - Train Accuracy: 0.9626, Validation Accuracy: 0.8846, Loss: 0.1471
# Epoch  38 Batch  400/1077 - Train Accuracy: 0.9039, Validation Accuracy: 0.8786, Loss: 0.1877
# Epoch  38 Batch  500/1077 - Train Accuracy: 0.9078, Validation Accuracy: 0.8857, Loss: 0.1611
# Epoch  38 Batch  600/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.8697, Loss: 0.1495
# Epoch  38 Batch  700/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.8789, Loss: 0.1487
# Epoch  38 Batch  800/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.8707, Loss: 0.1625
# Epoch  38 Batch  900/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.8828, Loss: 0.1747
# Epoch  38 Batch 1000/1077 - Train Accuracy: 0.9103, Validation Accuracy: 0.8700, Loss: 0.1616
# Epoch  39 Batch  100/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.8899, Loss: 0.1771
# Epoch  39 Batch  200/1077 - Train Accuracy: 0.8977, Validation Accuracy: 0.8786, Loss: 0.1588
# Epoch  39 Batch  300/1077 - Train Accuracy: 0.9692, Validation Accuracy: 0.8821, Loss: 0.1433
# Epoch  39 Batch  400/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.8704, Loss: 0.1783
# Epoch  39 Batch  500/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.8878, Loss: 0.1640
# Epoch  39 Batch  600/1077 - Train Accuracy: 0.9249, Validation Accuracy: 0.8665, Loss: 0.1490
# Epoch  39 Batch  700/1077 - Train Accuracy: 0.9078, Validation Accuracy: 0.8675, Loss: 0.1506
# Epoch  39 Batch  800/1077 - Train Accuracy: 0.8984, Validation Accuracy: 0.8732, Loss: 0.1561
# Epoch  39 Batch  900/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.8839, Loss: 0.1678
# Epoch  39 Batch 1000/1077 - Train Accuracy: 0.9103, Validation Accuracy: 0.8835, Loss: 0.1577
# Epoch  40 Batch  100/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.8892, Loss: 0.1582
# Epoch  40 Batch  200/1077 - Train Accuracy: 0.8875, Validation Accuracy: 0.8871, Loss: 0.1620
# Epoch  40 Batch  300/1077 - Train Accuracy: 0.9638, Validation Accuracy: 0.8860, Loss: 0.1398
# Epoch  40 Batch  400/1077 - Train Accuracy: 0.9121, Validation Accuracy: 0.8825, Loss: 0.1897
# Epoch  40 Batch  500/1077 - Train Accuracy: 0.9090, Validation Accuracy: 0.8821, Loss: 0.1525
# Epoch  40 Batch  600/1077 - Train Accuracy: 0.9312, Validation Accuracy: 0.8675, Loss: 0.1517
# Epoch  40 Batch  700/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.8903, Loss: 0.1531
# Epoch  40 Batch  800/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8952, Loss: 0.1656
# Epoch  40 Batch  900/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.8796, Loss: 0.1691
# Epoch  40 Batch 1000/1077 - Train Accuracy: 0.9189, Validation Accuracy: 0.8796, Loss: 0.1598
# Epoch  41 Batch  100/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.8949, Loss: 0.1582
# Epoch  41 Batch  200/1077 - Train Accuracy: 0.9039, Validation Accuracy: 0.8810, Loss: 0.1506
# Epoch  41 Batch  300/1077 - Train Accuracy: 0.9470, Validation Accuracy: 0.8956, Loss: 0.1405
# Epoch  41 Batch  400/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8984, Loss: 0.1813
# Epoch  41 Batch  500/1077 - Train Accuracy: 0.9285, Validation Accuracy: 0.8991, Loss: 0.1489
# Epoch  41 Batch  600/1077 - Train Accuracy: 0.9278, Validation Accuracy: 0.8885, Loss: 0.1415
# Epoch  41 Batch  700/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.8832, Loss: 0.1429
# Epoch  41 Batch  800/1077 - Train Accuracy: 0.8922, Validation Accuracy: 0.8981, Loss: 0.1583
# Epoch  41 Batch  900/1077 - Train Accuracy: 0.9195, Validation Accuracy: 0.8920, Loss: 0.1547
# Epoch  41 Batch 1000/1077 - Train Accuracy: 0.9193, Validation Accuracy: 0.8892, Loss: 0.1562
# Epoch  42 Batch  100/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.9016, Loss: 0.1474
# Epoch  42 Batch  200/1077 - Train Accuracy: 0.8812, Validation Accuracy: 0.8771, Loss: 0.1503
# Epoch  42 Batch  300/1077 - Train Accuracy: 0.9601, Validation Accuracy: 0.8942, Loss: 0.1421
# Epoch  42 Batch  400/1077 - Train Accuracy: 0.9078, Validation Accuracy: 0.8817, Loss: 0.1682
# Epoch  42 Batch  500/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.8888, Loss: 0.1458
# Epoch  42 Batch  600/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.8846, Loss: 0.1548
# Epoch  42 Batch  700/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.8917, Loss: 0.1401
# Epoch  42 Batch  800/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.8928, Loss: 0.1562
# Epoch  42 Batch  900/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.8888, Loss: 0.1560
# Epoch  42 Batch 1000/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.9002, Loss: 0.1410
# Epoch  43 Batch  100/1077 - Train Accuracy: 0.9207, Validation Accuracy: 0.8810, Loss: 0.1577
# Epoch  43 Batch  200/1077 - Train Accuracy: 0.9043, Validation Accuracy: 0.8842, Loss: 0.1542
# Epoch  43 Batch  300/1077 - Train Accuracy: 0.9568, Validation Accuracy: 0.8707, Loss: 0.1379
# Epoch  43 Batch  400/1077 - Train Accuracy: 0.9148, Validation Accuracy: 0.8814, Loss: 0.1802
# Epoch  43 Batch  500/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.8991, Loss: 0.1515
# Epoch  43 Batch  600/1077 - Train Accuracy: 0.9353, Validation Accuracy: 0.8853, Loss: 0.1452
# Epoch  43 Batch  700/1077 - Train Accuracy: 0.9191, Validation Accuracy: 0.8839, Loss: 0.1421
# Epoch  43 Batch  800/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.8963, Loss: 0.1470
# Epoch  43 Batch  900/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9059, Loss: 0.1599
# Epoch  43 Batch 1000/1077 - Train Accuracy: 0.9245, Validation Accuracy: 0.8750, Loss: 0.1423
# Epoch  44 Batch  100/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.8839, Loss: 0.1501
# Epoch  44 Batch  200/1077 - Train Accuracy: 0.9176, Validation Accuracy: 0.8871, Loss: 0.1501
# Epoch  44 Batch  300/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.8906, Loss: 0.1346
# Epoch  44 Batch  400/1077 - Train Accuracy: 0.9176, Validation Accuracy: 0.8768, Loss: 0.1691
# Epoch  44 Batch  500/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9006, Loss: 0.1374
# Epoch  44 Batch  600/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.8832, Loss: 0.1421
# Epoch  44 Batch  700/1077 - Train Accuracy: 0.9316, Validation Accuracy: 0.8888, Loss: 0.1359
# Epoch  44 Batch  800/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.8764, Loss: 0.1487
# Epoch  44 Batch  900/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.8814, Loss: 0.1568
# Epoch  44 Batch 1000/1077 - Train Accuracy: 0.9237, Validation Accuracy: 0.8988, Loss: 0.1324
# Epoch  45 Batch  100/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9055, Loss: 0.1495
# Epoch  45 Batch  200/1077 - Train Accuracy: 0.8891, Validation Accuracy: 0.8874, Loss: 0.1552
# Epoch  45 Batch  300/1077 - Train Accuracy: 0.9626, Validation Accuracy: 0.8963, Loss: 0.1410
# Epoch  45 Batch  400/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.8945, Loss: 0.1531
# Epoch  45 Batch  500/1077 - Train Accuracy: 0.9285, Validation Accuracy: 0.9006, Loss: 0.1362
# Epoch  45 Batch  600/1077 - Train Accuracy: 0.9338, Validation Accuracy: 0.8920, Loss: 0.1392
# Epoch  45 Batch  700/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.8963, Loss: 0.1382
# Epoch  45 Batch  800/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.8977, Loss: 0.1457
# Epoch  45 Batch  900/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.8803, Loss: 0.1574
# Epoch  45 Batch 1000/1077 - Train Accuracy: 0.9036, Validation Accuracy: 0.8860, Loss: 0.1458
# Epoch  46 Batch  100/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9034, Loss: 0.1499
# Epoch  46 Batch  200/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.8956, Loss: 0.1507
# Epoch  46 Batch  300/1077 - Train Accuracy: 0.9692, Validation Accuracy: 0.8952, Loss: 0.1272
# Epoch  46 Batch  400/1077 - Train Accuracy: 0.9207, Validation Accuracy: 0.8825, Loss: 0.1563
# Epoch  46 Batch  500/1077 - Train Accuracy: 0.9121, Validation Accuracy: 0.9070, Loss: 0.1255
# Epoch  46 Batch  600/1077 - Train Accuracy: 0.9416, Validation Accuracy: 0.8892, Loss: 0.1388
# Epoch  46 Batch  700/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.8988, Loss: 0.1356
# Epoch  46 Batch  800/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.8888, Loss: 0.1349
# Epoch  46 Batch  900/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.8924, Loss: 0.1509
# Epoch  46 Batch 1000/1077 - Train Accuracy: 0.9204, Validation Accuracy: 0.8860, Loss: 0.1375
# Epoch  47 Batch  100/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.8881, Loss: 0.1522
# Epoch  47 Batch  200/1077 - Train Accuracy: 0.9105, Validation Accuracy: 0.8871, Loss: 0.1397
# Epoch  47 Batch  300/1077 - Train Accuracy: 0.9581, Validation Accuracy: 0.9059, Loss: 0.1124
# Epoch  47 Batch  400/1077 - Train Accuracy: 0.9207, Validation Accuracy: 0.8828, Loss: 0.1839
# Epoch  47 Batch  500/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.8920, Loss: 0.1305
# Epoch  47 Batch  600/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.8899, Loss: 0.1360
# Epoch  47 Batch  700/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.8842, Loss: 0.1300
# Epoch  47 Batch  800/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9002, Loss: 0.1476
# Epoch  47 Batch  900/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.8995, Loss: 0.1378
# Epoch  47 Batch 1000/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.8857, Loss: 0.1369
# Epoch  48 Batch  100/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.8991, Loss: 0.1357
# Epoch  48 Batch  200/1077 - Train Accuracy: 0.8910, Validation Accuracy: 0.8910, Loss: 0.1537
# Epoch  48 Batch  300/1077 - Train Accuracy: 0.9667, Validation Accuracy: 0.8885, Loss: 0.1098
# Epoch  48 Batch  400/1077 - Train Accuracy: 0.9156, Validation Accuracy: 0.8949, Loss: 0.1596
# Epoch  48 Batch  500/1077 - Train Accuracy: 0.9195, Validation Accuracy: 0.8903, Loss: 0.1221
# Epoch  48 Batch  600/1077 - Train Accuracy: 0.9386, Validation Accuracy: 0.9066, Loss: 0.1277
# Epoch  48 Batch  700/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.8938, Loss: 0.1202
# Epoch  48 Batch  800/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.9112, Loss: 0.1440
# Epoch  48 Batch  900/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9155, Loss: 0.1426
# Epoch  48 Batch 1000/1077 - Train Accuracy: 0.9267, Validation Accuracy: 0.8885, Loss: 0.1422
# Epoch  49 Batch  100/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.8924, Loss: 0.1420
# Epoch  49 Batch  200/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8832, Loss: 0.1466
# Epoch  49 Batch  300/1077 - Train Accuracy: 0.9700, Validation Accuracy: 0.8881, Loss: 0.1183
# Epoch  49 Batch  400/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9045, Loss: 0.1591
# Epoch  49 Batch  500/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9041, Loss: 0.1331
# Epoch  49 Batch  600/1077 - Train Accuracy: 0.9364, Validation Accuracy: 0.8938, Loss: 0.1267
# Epoch  49 Batch  700/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.8722, Loss: 0.1235
# Epoch  49 Batch  800/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.8722, Loss: 0.1334
# Epoch  49 Batch  900/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.9002, Loss: 0.1547
# Epoch  49 Batch 1000/1077 - Train Accuracy: 0.9275, Validation Accuracy: 0.9006, Loss: 0.1421
# Epoch  50 Batch  100/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.8839, Loss: 0.1314
# Epoch  50 Batch  200/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.9023, Loss: 0.1484
# Epoch  50 Batch  300/1077 - Train Accuracy: 0.9626, Validation Accuracy: 0.8910, Loss: 0.1237
# Epoch  50 Batch  400/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.8981, Loss: 0.1674
# Epoch  50 Batch  500/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.8938, Loss: 0.1263
# Epoch  50 Batch  600/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9038, Loss: 0.1379
# Epoch  50 Batch  700/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.8906, Loss: 0.1316
# Epoch  50 Batch  800/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.9034, Loss: 0.1315
# Epoch  50 Batch  900/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9112, Loss: 0.1342
# Epoch  50 Batch 1000/1077 - Train Accuracy: 0.9189, Validation Accuracy: 0.9013, Loss: 0.1398
# Epoch  51 Batch  100/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9109, Loss: 0.1462
# Epoch  51 Batch  200/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.8871, Loss: 0.1395
# Epoch  51 Batch  300/1077 - Train Accuracy: 0.9725, Validation Accuracy: 0.9031, Loss: 0.1142
# Epoch  51 Batch  400/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.8974, Loss: 0.1566
# Epoch  51 Batch  500/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.8995, Loss: 0.1261
# Epoch  51 Batch  600/1077 - Train Accuracy: 0.9438, Validation Accuracy: 0.9116, Loss: 0.1271
# Epoch  51 Batch  700/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.8892, Loss: 0.1215
# Epoch  51 Batch  800/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9102, Loss: 0.1385
# Epoch  51 Batch  900/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.9105, Loss: 0.1441
# Epoch  51 Batch 1000/1077 - Train Accuracy: 0.9096, Validation Accuracy: 0.8913, Loss: 0.1274
# Epoch  52 Batch  100/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9112, Loss: 0.1278
# Epoch  52 Batch  200/1077 - Train Accuracy: 0.9125, Validation Accuracy: 0.9034, Loss: 0.1438
# Epoch  52 Batch  300/1077 - Train Accuracy: 0.9638, Validation Accuracy: 0.8988, Loss: 0.1152
# Epoch  52 Batch  400/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.8967, Loss: 0.1408
# Epoch  52 Batch  500/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9123, Loss: 0.1120
# Epoch  52 Batch  600/1077 - Train Accuracy: 0.9468, Validation Accuracy: 0.8949, Loss: 0.1383
# Epoch  52 Batch  700/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9073, Loss: 0.1157
# Epoch  52 Batch  800/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.8864, Loss: 0.1227
# Epoch  52 Batch  900/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.9180, Loss: 0.1457
# Epoch  52 Batch 1000/1077 - Train Accuracy: 0.9286, Validation Accuracy: 0.8984, Loss: 0.1257
# Epoch  53 Batch  100/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9098, Loss: 0.1416
# Epoch  53 Batch  200/1077 - Train Accuracy: 0.9156, Validation Accuracy: 0.8938, Loss: 0.1293
# Epoch  53 Batch  300/1077 - Train Accuracy: 0.9675, Validation Accuracy: 0.8881, Loss: 0.1294
# Epoch  53 Batch  400/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9034, Loss: 0.1569
# Epoch  53 Batch  500/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.8920, Loss: 0.1275
# Epoch  53 Batch  600/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.8910, Loss: 0.1384
# Epoch  53 Batch  700/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.8991, Loss: 0.1204
# Epoch  53 Batch  800/1077 - Train Accuracy: 0.9074, Validation Accuracy: 0.9197, Loss: 0.1262
# Epoch  53 Batch  900/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9059, Loss: 0.1403
# Epoch  53 Batch 1000/1077 - Train Accuracy: 0.9115, Validation Accuracy: 0.8981, Loss: 0.1177
# Epoch  54 Batch  100/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9116, Loss: 0.1299
# Epoch  54 Batch  200/1077 - Train Accuracy: 0.9105, Validation Accuracy: 0.8906, Loss: 0.1261
# Epoch  54 Batch  300/1077 - Train Accuracy: 0.9646, Validation Accuracy: 0.8949, Loss: 0.1129
# Epoch  54 Batch  400/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.8860, Loss: 0.1574
# Epoch  54 Batch  500/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.8970, Loss: 0.1045
# Epoch  54 Batch  600/1077 - Train Accuracy: 0.9323, Validation Accuracy: 0.8988, Loss: 0.1297
# Epoch  54 Batch  700/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.8974, Loss: 0.1120
# Epoch  54 Batch  800/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9080, Loss: 0.1251
# Epoch  54 Batch  900/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9205, Loss: 0.1380
# Epoch  54 Batch 1000/1077 - Train Accuracy: 0.9282, Validation Accuracy: 0.8906, Loss: 0.1200
# Epoch  55 Batch  100/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9261, Loss: 0.1208
# Epoch  55 Batch  200/1077 - Train Accuracy: 0.9039, Validation Accuracy: 0.9109, Loss: 0.1327
# Epoch  55 Batch  300/1077 - Train Accuracy: 0.9556, Validation Accuracy: 0.9031, Loss: 0.1172
# Epoch  55 Batch  400/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9016, Loss: 0.1435
# Epoch  55 Batch  500/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.8913, Loss: 0.1162
# Epoch  55 Batch  600/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9091, Loss: 0.1190
# Epoch  55 Batch  700/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.8984, Loss: 0.1180
# Epoch  55 Batch  800/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9329, Loss: 0.1174
# Epoch  55 Batch  900/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9187, Loss: 0.1295
# Epoch  55 Batch 1000/1077 - Train Accuracy: 0.9252, Validation Accuracy: 0.9091, Loss: 0.1218
# Epoch  56 Batch  100/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9169, Loss: 0.1267
# Epoch  56 Batch  200/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.8977, Loss: 0.1237
# Epoch  56 Batch  300/1077 - Train Accuracy: 0.9663, Validation Accuracy: 0.9038, Loss: 0.1113
# Epoch  56 Batch  400/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.8977, Loss: 0.1494
# Epoch  56 Batch  500/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9048, Loss: 0.1190
# Epoch  56 Batch  600/1077 - Train Accuracy: 0.9438, Validation Accuracy: 0.9041, Loss: 0.1059
# Epoch  56 Batch  700/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9027, Loss: 0.1039
# Epoch  56 Batch  800/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.9165, Loss: 0.1286
# Epoch  56 Batch  900/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9261, Loss: 0.1221
# Epoch  56 Batch 1000/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9041, Loss: 0.1199
# Epoch  57 Batch  100/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9020, Loss: 0.1247
# Epoch  57 Batch  200/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.8945, Loss: 0.1254
# Epoch  57 Batch  300/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9098, Loss: 0.1025
# Epoch  57 Batch  400/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9134, Loss: 0.1404
# Epoch  57 Batch  500/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9034, Loss: 0.1124
# Epoch  57 Batch  600/1077 - Train Accuracy: 0.9568, Validation Accuracy: 0.9268, Loss: 0.1178
# Epoch  57 Batch  700/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9041, Loss: 0.1080
# Epoch  57 Batch  800/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.9109, Loss: 0.1110
# Epoch  57 Batch  900/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9219, Loss: 0.1249
# Epoch  57 Batch 1000/1077 - Train Accuracy: 0.9405, Validation Accuracy: 0.8952, Loss: 0.1175
# Epoch  58 Batch  100/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9062, Loss: 0.1200
# Epoch  58 Batch  200/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.9073, Loss: 0.1136
# Epoch  58 Batch  300/1077 - Train Accuracy: 0.9502, Validation Accuracy: 0.9148, Loss: 0.1093
# Epoch  58 Batch  400/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.9023, Loss: 0.1592
# Epoch  58 Batch  500/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9116, Loss: 0.1077
# Epoch  58 Batch  600/1077 - Train Accuracy: 0.9479, Validation Accuracy: 0.9148, Loss: 0.1045
# Epoch  58 Batch  700/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9027, Loss: 0.1114
# Epoch  58 Batch  800/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9194, Loss: 0.1260
# Epoch  58 Batch  900/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9116, Loss: 0.1236
# Epoch  58 Batch 1000/1077 - Train Accuracy: 0.9282, Validation Accuracy: 0.9098, Loss: 0.1190
# Epoch  59 Batch  100/1077 - Train Accuracy: 0.9473, Validation Accuracy: 0.9176, Loss: 0.1229
# Epoch  59 Batch  200/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.9084, Loss: 0.1217
# Epoch  59 Batch  300/1077 - Train Accuracy: 0.9622, Validation Accuracy: 0.9283, Loss: 0.1085
# Epoch  59 Batch  400/1077 - Train Accuracy: 0.9336, Validation Accuracy: 0.9045, Loss: 0.1334
# Epoch  59 Batch  500/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9116, Loss: 0.1039
# Epoch  59 Batch  600/1077 - Train Accuracy: 0.9524, Validation Accuracy: 0.9148, Loss: 0.1144
# Epoch  59 Batch  700/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9098, Loss: 0.1185
# Epoch  59 Batch  800/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.9308, Loss: 0.1019
# Epoch  59 Batch  900/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9276, Loss: 0.1282
# Epoch  59 Batch 1000/1077 - Train Accuracy: 0.9260, Validation Accuracy: 0.9165, Loss: 0.1225
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# ### Plot accuracy

# %%
import matplotlib.pyplot as plt

plt.plot(train_acc_vec, label='Training Accuracy')
plt.plot(valid_acc_vec, label='Validation Accuracy')
plt.plot(loss_vec, label='Training Loss')
plt.legend()
_ = plt.ylim()
plt.show()
plt.gcf().clear()

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    in_lower = sentence.lower()
    word_ids = []
    for word in in_lower.split():
        if word in vocab_to_int:
            word_ids.append(vocab_to_int[word])
        else:
            word_ids.append(vocab_to_int['<UNK>'])
    return word_ids


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [46, 225, 13, 170, 152, 161, 32]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [68, 6, 272, 121, 109, 34, 108, 11, 1]
#   French Words: il a vu une petite voiture jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
