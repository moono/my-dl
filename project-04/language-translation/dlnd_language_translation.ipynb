# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)
print(view_sentence_range[0], ' ', view_sentence_range[1])

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# 0   10
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    EOS_id = target_vocab_to_int['<EOS>']
    source_id_text = []
    target_id_text = []
    for sentence in source_text.split('\n'):
        id_text = [source_vocab_to_int[word] for word in sentence.split()]            
        source_id_text.append(id_text)
    
    for sentence in target_text.split('\n'):
        id_text = [target_vocab_to_int[word] for word in sentence.split()]  
        id_text.append(EOS_id)
        target_id_text.append(id_text)
    
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    input_data = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    target_sequence_length = tf.placeholder(tf.int32, [None], name='target_sequence_length')
    max_target_len = tf.reduce_max(target_sequence_length, name='max_target_len')
    source_sequence_length = tf.placeholder(tf.int32, [None], name='source_sequence_length')
    
    return input_data, targets, learning_rate, keep_prob, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    GO_ID = target_vocab_to_int['<GO>']
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat( [tf.fill([batch_size, 1], GO_ID), ending], 1 )
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    # Embed the encoder
    enc_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)
    
    # Construct a stacked tf.contrib.rnn.LSTMCell wrapped in a tf.contrib.rnn.DropoutWrapper
    #enc_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.BasicLSTMCell(rnn_size), output_keep_prob=keep_prob) for _ in range(num_layers)], state_is_tuple=True )    
    def make_cell(rnn_size):
        enc_cell = tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2)))
        return enc_cell
    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    # Pass cell and embedded input to tf.nn.dynamic_rnn()
    enc_output, enc_state = tf.nn.dynamic_rnn(enc_cell, enc_embed_input, dtype=tf.float32)
    return enc_output, enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    # Create a tf.contrib.seq2seq.TrainingHelper
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input, 
                                                        sequence_length=target_sequence_length, 
                                                        time_major=False)
    # Create a tf.contrib.seq2seq.BasicDecoder
    # use dropout?
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, 
                                                       training_helper, 
                                                       encoder_state, 
                                                       output_layer)
    
    # Obtain the decoder outputs from tf.contrib.seq2seq.dynamic_decode
    train_dec_output, _ = tf.contrib.seq2seq.dynamic_decode(training_decoder, 
                                                            impute_finished=True, 
                                                            maximum_iterations=max_summary_length)

    return train_dec_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    # Create a tf.contrib.seq2seq.GreedyEmbeddingHelper
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
    greedy_embedding_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings, 
                                                                       start_tokens, 
                                                                       end_of_sequence_id)
    
    # Create a tf.contrib.seq2seq.BasicDecoder
    # use dropout?
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    infer_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, 
                                                    greedy_embedding_helper, 
                                                    encoder_state, 
                                                    output_layer)
    
    # Obtain the decoder outputs from tf.contrib.seq2seq.dynamic_decode
    infer_dec_output, _ = tf.contrib.seq2seq.dynamic_decode(infer_decoder, 
                                                            impute_finished=True, 
                                                            maximum_iterations=max_target_sequence_length)
    
    return infer_dec_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # prepare variables
    GO_ID = target_vocab_to_int['<GO>']
    EOS_ID = target_vocab_to_int['<EOS>']
    
    # Embed the target sequences, Construct the decoder LSTM cell
    #dec_embed_input = tf.contrib.layers.embed_sequence(dec_input, target_vocab_size, decoding_embedding_size)
    #dec_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.BasicLSTMCell(rnn_size), output_keep_prob=keep_prob) for _ in range(num_layers)], state_is_tuple=True )
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.DropoutWrapper(tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2)))
        return dec_cell
    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    # Output Layer
    #output_layer = lambda x: tf.contrib.layers.fully_connected(x, target_vocab_size, None, scope=decoding_scope)
    output_layer = Dense(target_vocab_size,
                         kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
        
    with tf.variable_scope("decoding") as decoding_scope:
        # Training Decoder
        train_logits = decoding_layer_train(encoder_state, 
                                            dec_cell, 
                                            dec_embed_input, 
                                            target_sequence_length, 
                                            max_target_sequence_length, 
                                            output_layer, 
                                            keep_prob)
    with tf.variable_scope("decoding", reuse=True) as decoding_scope:
        # Inference Decoder
        inference_logits = decoding_layer_infer(encoder_state, 
                                                dec_cell, 
                                                dec_embeddings, 
                                                GO_ID, 
                                                EOS_ID, 
                                                max_target_sequence_length, 
                                                target_vocab_size, 
                                                output_layer, 
                                                batch_size, 
                                                keep_prob)
    return train_logits, inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # Encode the input 
    enc_output, enc_state = encoding_layer(input_data, 
                                           rnn_size, 
                                           num_layers, 
                                           keep_prob, 
                                           source_sequence_length, 
                                           source_vocab_size, 
                                           enc_embedding_size)
    
    # Process target data
    dec_input = process_decoder_input(target_data, 
                                      target_vocab_to_int, 
                                      batch_size)
    
    # Decode the encoded input
    train_logits, inference_logits = decoding_layer(dec_input, 
                                                    enc_state,
                                                    target_sequence_length, 
                                                    max_target_sentence_length,
                                                    rnn_size, 
                                                    num_layers, 
                                                    target_vocab_to_int, 
                                                    target_vocab_size, 
                                                    batch_size, 
                                                    keep_prob, 
                                                    dec_embedding_size)
    return train_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 60
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 15
decoding_embedding_size = 15
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.5
display_step =
1077 - Train Accuracy: 0.8352, Validation Accuracy: 0.8164, Loss: 0.2900
# Epoch  21 Batch 1000/1077 - Train Accuracy: 0.8389, Validation Accuracy: 0.8164, Loss: 0.2572
# Epoch  22 Batch  100/1077 - Train Accuracy: 0.8156, Validation Accuracy: 0.8182, Loss: 0.2860
# Epoch  22 Batch  200/1077 - Train Accuracy: 0.8070, Validation Accuracy: 0.8274, Loss: 0.2936
# Epoch  22 Batch  300/1077 - Train Accuracy: 0.8137, Validation Accuracy: 0.8175, Loss: 0.2756
# Epoch  22 Batch  400/1077 - Train Accuracy: 0.8434, Validation Accuracy: 0.8001, Loss: 0.2999
# Epoch  22 Batch  500/1077 - Train Accuracy: 0.8195, Validation Accuracy: 0.8129, Loss: 0.2749
# Epoch  22 Batch  600/1077 - Train Accuracy: 0.8173, Validation Accuracy: 0.8068, Loss: 0.2682
# Epoch  22 Batch  700/1077 - Train Accuracy: 0.7992, Validation Accuracy: 0.7969, Loss: 0.2718
# Epoch  22 Batch  800/1077 - Train Accuracy: 0.8406, Validation Accuracy: 0.8192, Loss: 0.2719
# Epoch  22 Batch  900/1077 - Train Accuracy: 0.8461, Validation Accuracy: 0.8097, Loss: 0.2875
# Epoch  22 Batch 1000/1077 - Train Accuracy: 0.8542, Validation Accuracy: 0.8327, Loss: 0.2535
# Epoch  23 Batch  100/1077 - Train Accuracy: 0.8301, Validation Accuracy: 0.8274, Loss: 0.2668
# Epoch  23 Batch  200/1077 - Train Accuracy: 0.8258, Validation Accuracy: 0.8434, Loss: 0.2784
# Epoch  23 Batch  300/1077 - Train Accuracy: 0.8438, Validation Accuracy: 0.8228, Loss: 0.2713
# Epoch  23 Batch  400/1077 - Train Accuracy: 0.8250, Validation Accuracy: 0.8150, Loss: 0.2738
# Epoch  23 Batch  500/1077 - Train Accuracy: 0.8430, Validation Accuracy: 0.8242, Loss: 0.2504
# Epoch  23 Batch  600/1077 - Train Accuracy: 0.8218, Validation Accuracy: 0.8178, Loss: 0.2436
# Epoch  23 Batch  700/1077 - Train Accuracy: 0.8262, Validation Accuracy: 0.8207, Loss: 0.2509
# Epoch  23 Batch  800/1077 - Train Accuracy: 0.8465, Validation Accuracy: 0.8445, Loss: 0.2545
# Epoch  23 Batch  900/1077 - Train Accuracy: 0.8547, Validation Accuracy: 0.8459, Loss: 0.2773
# Epoch  23 Batch 1000/1077 - Train Accuracy: 0.8545, Validation Accuracy: 0.8459, Loss: 0.2383
# Epoch  24 Batch  100/1077 - Train Accuracy: 0.8168, Validation Accuracy: 0.8313, Loss: 0.2716
# Epoch  24 Batch  200/1077 - Train Accuracy: 0.8199, Validation Accuracy: 0.8377, Loss: 0.2658
# Epoch  24 Batch  300/1077 - Train Accuracy: 0.8413, Validation Accuracy: 0.8246, Loss: 0.2527
# Epoch  24 Batch  400/1077 - Train Accuracy: 0.8367, Validation Accuracy: 0.8427, Loss: 0.2819
# Epoch  24 Batch  500/1077 - Train Accuracy: 0.8492, Validation Accuracy: 0.8551, Loss: 0.2508
# Epoch  24 Batch  600/1077 - Train Accuracy: 0.8318, Validation Accuracy: 0.8232, Loss: 0.2364
# Epoch  24 Batch  700/1077 - Train Accuracy: 0.8664, Validation Accuracy: 0.8452, Loss: 0.2512
# Epoch  24 Batch  800/1077 - Train Accuracy: 0.8586, Validation Accuracy: 0.8452, Loss: 0.2420
# Epoch  24 Batch  900/1077 - Train Accuracy: 0.8602, Validation Accuracy: 0.8459, Loss: 0.2787
# Epoch  24 Batch 1000/1077 - Train Accuracy: 0.8575, Validation Accuracy: 0.8608, Loss: 0.2273
# Epoch  25 Batch  100/1077 - Train Accuracy: 0.8547, Validation Accuracy: 0.8626, Loss: 0.2553
# Epoch  25 Batch  200/1077 - Train Accuracy: 0.8398, Validation Accuracy: 0.8487, Loss: 0.2584
# Epoch  25 Batch  300/1077 - Train Accuracy: 0.8536, Validation Accuracy: 0.8487, Loss: 0.2433
# Epoch  25 Batch  400/1077 - Train Accuracy: 0.8648, Validation Accuracy: 0.8576, Loss: 0.2683
# Epoch  25 Batch  500/1077 - Train Accuracy: 0.8504, Validation Accuracy: 0.8484, Loss: 0.2387
# Epoch  25 Batch  600/1077 - Train Accuracy: 0.8523, Validation Accuracy: 0.8704, Loss: 0.2337
# Epoch  25 Batch  700/1077 - Train Accuracy: 0.8809, Validation Accuracy: 0.8494, Loss: 0.2330
# Epoch  25 Batch  800/1077 - Train Accuracy: 0.8777, Validation Accuracy: 0.8494, Loss: 0.2438
# Epoch  25 Batch  900/1077 - Train Accuracy: 0.8539, Validation Accuracy: 0.8633, Loss: 0.2445
# Epoch  25 Batch 1000/1077 - Train Accuracy: 0.8597, Validation Accuracy: 0.8636, Loss: 0.2125
# Epoch  26 Batch  100/1077 - Train Accuracy: 0.8637, Validation Accuracy: 0.8643, Loss: 0.2518
# Epoch  26 Batch  200/1077 - Train Accuracy: 0.8355, Validation Accuracy: 0.8562, Loss: 0.2452
# Epoch  26 Batch  300/1077 - Train Accuracy: 0.8660, Validation Accuracy: 0.8711, Loss: 0.2371
# Epoch  26 Batch  400/1077 - Train Accuracy: 0.8445, Validation Accuracy: 0.8391, Loss: 0.2722
# Epoch  26 Batch  500/1077 - Train Accuracy: 0.8602, Validation Accuracy: 0.8707, Loss: 0.2329
# Epoch  26 Batch  600/1077 - Train Accuracy: 0.8538, Validation Accuracy: 0.8626, Loss: 0.2294
# Epoch  26 Batch  700/1077 - Train Accuracy: 0.8820, Validation Accuracy: 0.8569, Loss: 0.2212
# Epoch  26 Batch  800/1077 - Train Accuracy: 0.8727, Validation Accuracy: 0.8381, Loss: 0.2264
# Epoch  26 Batch  900/1077 - Train Accuracy: 0.8609, Validation Accuracy: 0.8516, Loss: 0.2408
# Epoch  26 Batch 1000/1077 - Train Accuracy: 0.8690, Validation Accuracy: 0.8711, Loss: 0.2143
# Epoch  27 Batch  100/1077 - Train Accuracy: 0.8566, Validation Accuracy: 0.8530, Loss: 0.2291
# Epoch  27 Batch  200/1077 - Train Accuracy: 0.8492, Validation Accuracy: 0.8796, Loss: 0.2509
# Epoch  27 Batch  300/1077 - Train Accuracy: 0.8655, Validation Accuracy: 0.8746, Loss: 0.2212
# Epoch  27 Batch  400/1077 - Train Accuracy: 0.8590, Validation Accuracy: 0.8484, Loss: 0.2528
# Epoch  27 Batch  500/1077 - Train Accuracy: 0.8633, Validation Accuracy: 0.8583, Loss: 0.2073
# Epoch  27 Batch  600/1077 - Train Accuracy: 0.8534, Validation Accuracy: 0.8668, Loss: 0.2199
# Epoch  27 Batch  700/1077 - Train Accuracy: 0.8859, Validation Accuracy: 0.8647, Loss: 0.2230
# Epoch  27 Batch  800/1077 - Train Accuracy: 0.8777, Validation Accuracy: 0.8761, Loss: 0.2180
# Epoch  27 Batch  900/1077 - Train Accuracy: 0.8797, Validation Accuracy: 0.8693, Loss: 0.2451
# Epoch  27 Batch 1000/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8533, Loss: 0.2119
# Epoch  28 Batch  100/1077 - Train Accuracy: 0.8672, Validation Accuracy: 0.8821, Loss: 0.2271
# Epoch  28 Batch  200/1077 - Train Accuracy: 0.8715, Validation Accuracy: 0.8828, Loss: 0.2233
# Epoch  28 Batch  300/1077 - Train Accuracy: 0.8808, Validation Accuracy: 0.8707, Loss: 0.2092
# Epoch  28 Batch  400/1077 - Train Accuracy: 0.8879, Validation Accuracy: 0.8558, Loss: 0.2446
# Epoch  28 Batch  500/1077 - Train Accuracy: 0.8707, Validation Accuracy: 0.8537, Loss: 0.1986
# Epoch  28 Batch  600/1077 - Train Accuracy: 0.8702, Validation Accuracy: 0.8768, Loss: 0.2199
# Epoch  28 Batch  700/1077 - Train Accuracy: 0.8953, Validation Accuracy: 0.8491, Loss: 0.1965
# Epoch  28 Batch  800/1077 - Train Accuracy: 0.8801, Validation Accuracy: 0.8569, Loss: 0.2296
# Epoch  28 Batch  900/1077 - Train Accuracy: 0.8672, Validation Accuracy: 0.8686, Loss: 0.2364
# Epoch  28 Batch 1000/1077 - Train Accuracy: 0.8746, Validation Accuracy: 0.8722, Loss: 0.2034
# Epoch  29 Batch  100/1077 - Train Accuracy: 0.8578, Validation Accuracy: 0.8803, Loss: 0.2188
# Epoch  29 Batch  200/1077 - Train Accuracy: 0.8562, Validation Accuracy: 0.8576, Loss: 0.2225
# Epoch  29 Batch  300/1077 - Train Accuracy: 0.8766, Validation Accuracy: 0.8817, Loss: 0.2231
# Epoch  29 Batch  400/1077 - Train Accuracy: 0.8855, Validation Accuracy: 0.8714, Loss: 0.2386
# Epoch  29 Batch  500/1077 - Train Accuracy: 0.8715, Validation Accuracy: 0.8793, Loss: 0.2012
# Epoch  29 Batch  600/1077 - Train Accuracy: 0.8683, Validation Accuracy: 0.8665, Loss: 0.2166
# Epoch  29 Batch  700/1077 - Train Accuracy: 0.8812, Validation Accuracy: 0.8587, Loss: 0.2150
# Epoch  29 Batch  800/1077 - Train Accuracy: 0.8895, Validation Accuracy: 0.8810, Loss: 0.2117
# Epoch  29 Batch  900/1077 - Train Accuracy: 0.8871, Validation Accuracy: 0.8707, Loss: 0.2242
# Epoch  29 Batch 1000/1077 - Train Accuracy: 0.8709, Validation Accuracy: 0.8913, Loss: 0.2077
# Epoch  30 Batch  100/1077 - Train Accuracy: 0.8559, Validation Accuracy: 0.8583, Loss: 0.2225
# Epoch  30 Batch  200/1077 - Train Accuracy: 0.8598, Validation Accuracy: 0.8896, Loss: 0.2147
# Epoch  30 Batch  300/1077 - Train Accuracy: 0.9058, Validation Accuracy: 0.8878, Loss: 0.2100
# Epoch  30 Batch  400/1077 - Train Accuracy: 0.8742, Validation Accuracy: 0.8544, Loss: 0.2324
# Epoch  30 Batch  500/1077 - Train Accuracy: 0.8555, Validation Accuracy: 0.8640, Loss: 0.1911
# Epoch  30 Batch  600/1077 - Train Accuracy: 0.8832, Validation Accuracy: 0.8800, Loss: 0.2008
# Epoch  30 Batch  700/1077 - Train Accuracy: 0.8977, Validation Accuracy: 0.8636, Loss: 0.2073
# Epoch  30 Batch  800/1077 - Train Accuracy: 0.8875, Validation Accuracy: 0.8675, Loss: 0.2018
# Epoch  30 Batch  900/1077 - Train Accuracy: 0.8680, Validation Accuracy: 0.8714, Loss: 0.2102
# Epoch  30 Batch 1000/1077 - Train Accuracy: 0.8798, Validation Accuracy: 0.8739, Loss: 0.1922
# Epoch  31 Batch  100/1077 - Train Accuracy: 0.8852, Validation Accuracy: 0.8778, Loss: 0.2048
# Epoch  31 Batch  200/1077 - Train Accuracy: 0.8738, Validation Accuracy: 0.8725, Loss: 0.2112
# Epoch  31 Batch  300/1077 - Train Accuracy: 0.9091, Validation Accuracy: 0.8963, Loss: 0.1874
# Epoch  31 Batch  400/1077 - Train Accuracy: 0.8730, Validation Accuracy: 0.8519, Loss: 0.2182
# Epoch  31 Batch  500/1077 - Train Accuracy: 0.8809, Validation Accuracy: 0.8750, Loss: 0.1961
# Epoch  31 Batch  600/1077 - Train Accuracy: 0.8832, Validation Accuracy: 0.8707, Loss: 0.2052
# Epoch  31 Batch  700/1077 - Train Accuracy: 0.9199, Validation Accuracy: 0.8597, Loss: 0.2001
# Epoch  31 Batch  800/1077 - Train Accuracy: 0.8934, Validation Accuracy: 0.8576, Loss: 0.1953
# Epoch  31 Batch  900/1077 - Train Accuracy: 0.8832, Validation Accuracy: 0.8881, Loss: 0.2163
# Epoch  31 Batch 1000/1077 - Train Accuracy: 0.8865, Validation Accuracy: 0.8700, Loss: 0.1853
# Epoch  32 Batch  100/1077 - Train Accuracy: 0.9074, Validation Accuracy: 0.8832, Loss: 0.2011
# Epoch  32 Batch  200/1077 - Train Accuracy: 0.8691, Validation Accuracy: 0.8956, Loss: 0.1966
# Epoch  32 Batch  300/1077 - Train Accuracy: 0.9050, Validation Accuracy: 0.8892, Loss: 0.1918
# Epoch  32 Batch  400/1077 - Train Accuracy: 0.8789, Validation Accuracy: 0.8743, Loss: 0.2259
# Epoch  32 Batch  500/1077 - Train Accuracy: 0.9031, Validation Accuracy: 0.8942, Loss: 0.1782
# Epoch  32 Batch  600/1077 - Train Accuracy: 0.8880, Validation Accuracy: 0.8899, Loss: 0.1841
# Epoch  32 Batch  700/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.8892, Loss: 0.1646
# Epoch  32 Batch  800/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8697, Loss: 0.2107
# Epoch  32 Batch  900/1077 - Train Accuracy: 0.8902, Validation Accuracy: 0.8743, Loss: 0.2116
# Epoch  32 Batch 1000/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8871, Loss: 0.1748
# Epoch  33 Batch  100/1077 - Train Accuracy: 0.8926, Validation Accuracy: 0.8864, Loss: 0.1927
# Epoch  33 Batch  200/1077 - Train Accuracy: 0.8715, Validation Accuracy: 0.8949, Loss: 0.1887
# Epoch  33 Batch  300/1077 - Train Accuracy: 0.9194, Validation Accuracy: 0.8924, Loss: 0.1854
# Epoch  33 Batch  400/1077 - Train Accuracy: 0.8930, Validation Accuracy: 0.8849, Loss: 0.2065
# Epoch  33 Batch  500/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.8881, Loss: 0.1884
# Epoch  33 Batch  600/1077 - Train Accuracy: 0.9178, Validation Accuracy: 0.8903, Loss: 0.1866
# Epoch  33 Batch  700/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.8796, Loss: 0.1861
# Epoch  33 Batch  800/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.8800, Loss: 0.1749
# Epoch  33 Batch  900/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.8896, Loss: 0.1953
# Epoch  33 Batch 1000/1077 - Train Accuracy: 0.8895, Validation Accuracy: 0.8963, Loss: 0.1901
# Epoch  34 Batch  100/1077 - Train Accuracy: 0.9160, Validation Accuracy: 0.8931, Loss: 0.1893
# Epoch  34 Batch  200/1077 - Train Accuracy: 0.8898, Validation Accuracy: 0.8928, Loss: 0.1905
# Epoch  34 Batch  300/1077 - Train Accuracy: 0.9396, Validation Accuracy: 0.8991, Loss: 0.1781
# Epoch  34 Batch  400/1077 - Train Accuracy: 0.9000, Validation Accuracy: 0.8881, Loss: 0.2091
# Epoch  34 Batch  500/1077 - Train Accuracy: 0.9121, Validation Accuracy: 0.8970, Loss: 0.1673
# Epoch  34 Batch  600/1077 - Train Accuracy: 0.9077, Validation Accuracy: 0.8945, Loss: 0.1813
# Epoch  34 Batch  700/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.8796, Loss: 0.1751
# Epoch  34 Batch  800/1077 - Train Accuracy: 0.8707, Validation Accuracy: 0.8896, Loss: 0.1731
# Epoch  34 Batch  900/1077 - Train Accuracy: 0.8953, Validation Accuracy: 0.8878, Loss: 0.1926
# Epoch  34 Batch 1000/1077 - Train Accuracy: 0.9018, Validation Accuracy: 0.8995, Loss: 0.1663
# Epoch  35 Batch  100/1077 - Train Accuracy: 0.9000, Validation Accuracy: 0.8935, Loss: 0.1878
# Epoch  35 Batch  200/1077 - Train Accuracy: 0.8840, Validation Accuracy: 0.8967, Loss: 0.1849
# Epoch  35 Batch  300/1077 - Train Accuracy: 0.9186, Validation Accuracy: 0.8981, Loss: 0.1673
# Epoch  35 Batch  400/1077 - Train Accuracy: 0.9043, Validation Accuracy: 0.8871, Loss: 0.2040
# Epoch  35 Batch  500/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.8917, Loss: 0.1679
# Epoch  35 Batch  600/1077 - Train Accuracy: 0.9085, Validation Accuracy: 0.8942, Loss: 0.1776
# Epoch  35 Batch  700/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.8725, Loss: 0.1599
# Epoch  35 Batch  800/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.8750, Loss: 0.1581
# Epoch  35 Batch  900/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.9009, Loss: 0.1994
# Epoch  35 Batch 1000/1077 - Train Accuracy: 0.9077, Validation Accuracy: 0.8913, Loss: 0.1677
# Epoch  36 Batch  100/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.9034, Loss: 0.1724
# Epoch  36 Batch  200/1077 - Train Accuracy: 0.8941, Validation Accuracy: 0.9027, Loss: 0.1728
# Epoch  36 Batch  300/1077 - Train Accuracy: 0.9486, Validation Accuracy: 0.8736, Loss: 0.1603
# Epoch  36 Batch  400/1077 - Train Accuracy: 0.8930, Validation Accuracy: 0.8892, Loss: 0.1943
# Epoch  36 Batch  500/1077 - Train Accuracy: 0.9121, Validation Accuracy: 0.8945, Loss: 0.1613
# Epoch  36 Batch  600/1077 - Train Accuracy: 0.9055, Validation Accuracy: 0.8967, Loss: 0.1630
# Epoch  36 Batch  700/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.8807, Loss: 0.1531
# Epoch  36 Batch  800/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8970, Loss: 0.1754
# Epoch  36 Batch  900/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9006, Loss: 0.1753
# Epoch  36 Batch 1000/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8942, Loss: 0.1496
# Epoch  37 Batch  100/1077 - Train Accuracy: 0.9277, Validation Accuracy: 0.9084, Loss: 0.1667
# Epoch  37 Batch  200/1077 - Train Accuracy: 0.8871, Validation Accuracy: 0.8960, Loss: 0.1815
# Epoch  37 Batch  300/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.8920, Loss: 0.1576
# Epoch  37 Batch  400/1077 - Train Accuracy: 0.9078, Validation Accuracy: 0.8846, Loss: 0.1973
# Epoch  37 Batch  500/1077 - Train Accuracy: 0.9336, Validation Accuracy: 0.8991, Loss: 0.1604
# Epoch  37 Batch  600/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.8991, Loss: 0.1629
# Epoch  37 Batch  700/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.8963, Loss: 0.1511
# Epoch  37 Batch  800/1077 - Train Accuracy: 0.9207, Validation Accuracy: 0.8849, Loss: 0.1647
# Epoch  37 Batch  900/1077 - Train Accuracy: 0.9109, Validation Accuracy: 0.8995, Loss: 0.1791
# Epoch  37 Batch 1000/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.9077, Loss: 0.1573
# Epoch  38 Batch  100/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.8974, Loss: 0.1658
# Epoch  38 Batch  200/1077 - Train Accuracy: 0.8809, Validation Accuracy: 0.9084, Loss: 0.1795
# Epoch  38 Batch  300/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.8942, Loss: 0.1556
# Epoch  38 Batch  400/1077 - Train Accuracy: 0.8891, Validation Accuracy: 0.8871, Loss: 0.1695
# Epoch  38 Batch  500/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.9016, Loss: 0.1608
# Epoch  38 Batch  600/1077 - Train Accuracy: 0.9107, Validation Accuracy: 0.9041, Loss: 0.1494
# Epoch  38 Batch  700/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.8732, Loss: 0.1654
# Epoch  38 Batch  800/1077 - Train Accuracy: 0.9105, Validation Accuracy: 0.8942, Loss: 0.1673
# Epoch  38 Batch  900/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.8988, Loss: 0.1679
# Epoch  38 Batch 1000/1077 - Train Accuracy: 0.9029, Validation Accuracy: 0.8991, Loss: 0.1558
# Epoch  39 Batch  100/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.8977, Loss: 0.1612
# Epoch  39 Batch  200/1077 - Train Accuracy: 0.8953, Validation Accuracy: 0.8935, Loss: 0.1639
# Epoch  39 Batch  300/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.8857, Loss: 0.1517
# Epoch  39 Batch  400/1077 - Train Accuracy: 0.9031, Validation Accuracy: 0.8903, Loss: 0.1729
# Epoch  39 Batch  500/1077 - Train Accuracy: 0.9336, Validation Accuracy: 0.8878, Loss: 0.1468
# Epoch  39 Batch  600/1077 - Train Accuracy: 0.9159, Validation Accuracy: 0.8924, Loss: 0.1462
# Epoch  39 Batch  700/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9031, Loss: 0.1594
# Epoch  39 Batch  800/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.8881, Loss: 0.1629
# Epoch  39 Batch  900/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.8981, Loss: 0.1701
# Epoch  39 Batch 1000/1077 - Train Accuracy: 0.9122, Validation Accuracy: 0.9062, Loss: 0.1504
# Epoch  40 Batch  100/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9020, Loss: 0.1579
# Epoch  40 Batch  200/1077 - Train Accuracy: 0.8953, Validation Accuracy: 0.9084, Loss: 0.1582
# Epoch  40 Batch  300/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.8960, Loss: 0.1475
# Epoch  40 Batch  400/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.9009, Loss: 0.1723
# Epoch  40 Batch  500/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9105, Loss: 0.1441
# Epoch  40 Batch  600/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8995, Loss: 0.1465
# Epoch  40 Batch  700/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.8683, Loss: 0.1479
# Epoch  40 Batch  800/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9048, Loss: 0.1571
# Epoch  40 Batch  900/1077 - Train Accuracy: 0.9074, Validation Accuracy: 0.9002, Loss: 0.1801
# Epoch  40 Batch 1000/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.9077, Loss: 0.1306
# Epoch  41 Batch  100/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.8952, Loss: 0.1527
# Epoch  41 Batch  200/1077 - Train Accuracy: 0.8906, Validation Accuracy: 0.8949, Loss: 0.1567
# Epoch  41 Batch  300/1077 - Train Accuracy: 0.9502, Validation Accuracy: 0.8945, Loss: 0.1479
# Epoch  41 Batch  400/1077 - Train Accuracy: 0.9082, Validation Accuracy: 0.9162, Loss: 0.1672
# Epoch  41 Batch  500/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.8906, Loss: 0.1429
# Epoch  41 Batch  600/1077 - Train Accuracy: 0.9115, Validation Accuracy: 0.8945, Loss: 0.1574
# Epoch  41 Batch  700/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.8917, Loss: 0.1350
# Epoch  41 Batch  800/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8942, Loss: 0.1547
# Epoch  41 Batch  900/1077 - Train Accuracy: 0.9117, Validation Accuracy: 0.8945, Loss: 0.1740
# Epoch  41 Batch 1000/1077 - Train Accuracy: 0.9200, Validation Accuracy: 0.9041, Loss: 0.1559
# Epoch  42 Batch  100/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9091, Loss: 0.1506
# Epoch  42 Batch  200/1077 - Train Accuracy: 0.8996, Validation Accuracy: 0.8999, Loss: 0.1583
# Epoch  42 Batch  300/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9034, Loss: 0.1452
# Epoch  42 Batch  400/1077 - Train Accuracy: 0.9098, Validation Accuracy: 0.8917, Loss: 0.1721
# Epoch  42 Batch  500/1077 - Train Accuracy: 0.9277, Validation Accuracy: 0.9109, Loss: 0.1503
# Epoch  42 Batch  600/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.9098, Loss: 0.1608
# Epoch  42 Batch  700/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9052, Loss: 0.1559
# Epoch  42 Batch  800/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.8899, Loss: 0.1519
# Epoch  42 Batch  900/1077 - Train Accuracy: 0.9160, Validation Accuracy: 0.9020, Loss: 0.1618
# Epoch  42 Batch 1000/1077 - Train Accuracy: 0.9036, Validation Accuracy: 0.9077, Loss: 0.1386
# Epoch  43 Batch  100/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9073, Loss: 0.1575
# Epoch  43 Batch  200/1077 - Train Accuracy: 0.9160, Validation Accuracy: 0.9080, Loss: 0.1441
# Epoch  43 Batch  300/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9102, Loss: 0.1407
# Epoch  43 Batch  400/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8888, Loss: 0.1638
# Epoch  43 Batch  500/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.9041, Loss: 0.1323
# Epoch  43 Batch  600/1077 - Train Accuracy: 0.9286, Validation Accuracy: 0.9045, Loss: 0.1335
# Epoch  43 Batch  700/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.8817, Loss: 0.1360
# Epoch  43 Batch  800/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.8906, Loss: 0.1503
# Epoch  43 Batch  900/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.9109, Loss: 0.1759
# Epoch  43 Batch 1000/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.9055, Loss: 0.1409
# Epoch  44 Batch  100/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9016, Loss: 0.1431
# Epoch  44 Batch  200/1077 - Train Accuracy: 0.8945, Validation Accuracy: 0.9155, Loss: 0.1503
# Epoch  44 Batch  300/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9109, Loss: 0.1384
# Epoch  44 Batch  400/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9013, Loss: 0.1564
# Epoch  44 Batch  500/1077 - Train Accuracy: 0.9316, Validation Accuracy: 0.9116, Loss: 0.1328
# Epoch  44 Batch  600/1077 - Train Accuracy: 0.9249, Validation Accuracy: 0.9155, Loss: 0.1367
# Epoch  44 Batch  700/1077 - Train Accuracy: 0.9398, Validation Accuracy: 0.9013, Loss: 0.1254
# Epoch  44 Batch  800/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.9077, Loss: 0.1454
# Epoch  44 Batch  900/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.9080, Loss: 0.1629
# Epoch  44 Batch 1000/1077 - Train Accuracy: 0.9226, Validation Accuracy: 0.9059, Loss: 0.1370
# Epoch  45 Batch  100/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.9212, Loss: 0.1397
# Epoch  45 Batch  200/1077 - Train Accuracy: 0.9012, Validation Accuracy: 0.9084, Loss: 0.1495
# Epoch  45 Batch  300/1077 - Train Accuracy: 0.9478, Validation Accuracy: 0.8977, Loss: 0.1338
# Epoch  45 Batch  400/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.8924, Loss: 0.1795
# Epoch  45 Batch  500/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9027, Loss: 0.1308
# Epoch  45 Batch  600/1077 - Train Accuracy: 0.9237, Validation Accuracy: 0.9087, Loss: 0.1464
# Epoch  45 Batch  700/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9006, Loss: 0.1389
# Epoch  45 Batch  800/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9098, Loss: 0.1379
# Epoch  45 Batch  900/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9173, Loss: 0.1563
# Epoch  45 Batch 1000/1077 - Train Accuracy: 0.9144, Validation Accuracy: 0.9151, Loss: 0.1361
# Epoch  46 Batch  100/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.9084, Loss: 0.1427
# Epoch  46 Batch  200/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.9087, Loss: 0.1401
# Epoch  46 Batch  300/1077 - Train Accuracy: 0.9597, Validation Accuracy: 0.9070, Loss: 0.1285
# Epoch  46 Batch  400/1077 - Train Accuracy: 0.9195, Validation Accuracy: 0.9162, Loss: 0.1539
# Epoch  46 Batch  500/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9158, Loss: 0.1361
# Epoch  46 Batch  600/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9158, Loss: 0.1316
# Epoch  46 Batch  700/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.8981, Loss: 0.1367
# Epoch  46 Batch  800/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9052, Loss: 0.1299
# Epoch  46 Batch  900/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.9098, Loss: 0.1595
# Epoch  46 Batch 1000/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.9169, Loss: 0.1350
# Epoch  47 Batch  100/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9148, Loss: 0.1512
# Epoch  47 Batch  200/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.9208, Loss: 0.1582
# Epoch  47 Batch  300/1077 - Train Accuracy: 0.9511, Validation Accuracy: 0.9087, Loss: 0.1185
# Epoch  47 Batch  400/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.9165, Loss: 0.1527
# Epoch  47 Batch  500/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9105, Loss: 0.1414
# Epoch  47 Batch  600/1077 - Train Accuracy: 0.9167, Validation Accuracy: 0.9031, Loss: 0.1257
# Epoch  47 Batch  700/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.8899, Loss: 0.1303
# Epoch  47 Batch  800/1077 - Train Accuracy: 0.9250, Validation Accuracy: 0.9002, Loss: 0.1331
# Epoch  47 Batch  900/1077 - Train Accuracy: 0.9148, Validation Accuracy: 0.9130, Loss: 0.1511
# Epoch  47 Batch 1000/1077 - Train Accuracy: 0.9226, Validation Accuracy: 0.9020, Loss: 0.1253
# Epoch  48 Batch  100/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9258, Loss: 0.1282
# Epoch  48 Batch  200/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.9052, Loss: 0.1429
# Epoch  48 Batch  300/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9066, Loss: 0.1381
# Epoch  48 Batch  400/1077 - Train Accuracy: 0.9148, Validation Accuracy: 0.9222, Loss: 0.1586
# Epoch  48 Batch  500/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9116, Loss: 0.1309
# Epoch  48 Batch  600/1077 - Train Accuracy: 0.9263, Validation Accuracy: 0.9254, Loss: 0.1358
# Epoch  48 Batch  700/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9098, Loss: 0.1256
# Epoch  48 Batch  800/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9126, Loss: 0.1343
# Epoch  48 Batch  900/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.9094, Loss: 0.1584
# Epoch  48 Batch 1000/1077 - Train Accuracy: 0.9122, Validation Accuracy: 0.9052, Loss: 0.1261
# Epoch  49 Batch  100/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9329, Loss: 0.1342
# Epoch  49 Batch  200/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9070, Loss: 0.1400
# Epoch  49 Batch  300/1077 - Train Accuracy: 0.9560, Validation Accuracy: 0.9190, Loss: 0.1434
# Epoch  49 Batch  400/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.9105, Loss: 0.1577
# Epoch  49 Batch  500/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9066, Loss: 0.1211
# Epoch  49 Batch  600/1077 - Train Accuracy: 0.9156, Validation Accuracy: 0.9094, Loss: 0.1413
# Epoch  49 Batch  700/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9112, Loss: 0.1243
# Epoch  49 Batch  800/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9141, Loss: 0.1321
# Epoch  49 Batch  900/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.9219, Loss: 0.1556
# Epoch  49 Batch 1000/1077 - Train Accuracy: 0.9204, Validation Accuracy: 0.9151, Loss: 0.1243
# Epoch  50 Batch  100/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9162, Loss: 0.1289
# Epoch  50 Batch  200/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9208, Loss: 0.1332
# Epoch  50 Batch  300/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9130, Loss: 0.1211
# Epoch  50 Batch  400/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.9169, Loss: 0.1678
# Epoch  50 Batch  500/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9134, Loss: 0.1285
# Epoch  50 Batch  600/1077 - Train Accuracy: 0.9148, Validation Accuracy: 0.9237, Loss: 0.1252
# Epoch  50 Batch  700/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9094, Loss: 0.1179
# Epoch  50 Batch  800/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9141, Loss: 0.1262
# Epoch  50 Batch  900/1077 - Train Accuracy: 0.9043, Validation Accuracy: 0.9233, Loss: 0.1617
# Epoch  50 Batch 1000/1077 - Train Accuracy: 0.9126, Validation Accuracy: 0.9261, Loss: 0.1246
# Epoch  51 Batch  100/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9126, Loss: 0.1272
# Epoch  51 Batch  200/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9240, Loss: 0.1410
# Epoch  51 Batch  300/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9062, Loss: 0.1230
# Epoch  51 Batch  400/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.9205, Loss: 0.1442
# Epoch  51 Batch  500/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9112, Loss: 0.1293
# Epoch  51 Batch  600/1077 - Train Accuracy: 0.9401, Validation Accuracy: 0.9158, Loss: 0.1416
# Epoch  51 Batch  700/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9244, Loss: 0.1165
# Epoch  51 Batch  800/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9027, Loss: 0.1298
# Epoch  51 Batch  900/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.9126, Loss: 0.1412
# Epoch  51 Batch 1000/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9119, Loss: 0.1235
# Epoch  52 Batch  100/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.9208, Loss: 0.1239
# Epoch  52 Batch  200/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.9176, Loss: 0.1298
# Epoch  52 Batch  300/1077 - Train Accuracy: 0.9568, Validation Accuracy: 0.9116, Loss: 0.1293
# Epoch  52 Batch  400/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.9091, Loss: 0.1579
# Epoch  52 Batch  500/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9180, Loss: 0.1146
# Epoch  52 Batch  600/1077 - Train Accuracy: 0.9174, Validation Accuracy: 0.9329, Loss: 0.1216
# Epoch  52 Batch  700/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9173, Loss: 0.1171
# Epoch  52 Batch  800/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9155, Loss: 0.1145
# Epoch  52 Batch  900/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.9155, Loss: 0.1427
# Epoch  52 Batch 1000/1077 - Train Accuracy: 0.9185, Validation Accuracy: 0.9286, Loss: 0.1212
# Epoch  53 Batch  100/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9393, Loss: 0.1202
# Epoch  53 Batch  200/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9276, Loss: 0.1292
# Epoch  53 Batch  300/1077 - Train Accuracy: 0.9560, Validation Accuracy: 0.9148, Loss: 0.1188
# Epoch  53 Batch  400/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.9212, Loss: 0.1374
# Epoch  53 Batch  500/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9109, Loss: 0.1164
# Epoch  53 Batch  600/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9332, Loss: 0.1262
# Epoch  53 Batch  700/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9357, Loss: 0.1164
# Epoch  53 Batch  800/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.9315, Loss: 0.1161
# Epoch  53 Batch  900/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9244, Loss: 0.1480
# Epoch  53 Batch 1000/1077 - Train Accuracy: 0.9148, Validation Accuracy: 0.9165, Loss: 0.1198
# Epoch  54 Batch  100/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.9339, Loss: 0.1178
# Epoch  54 Batch  200/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9322, Loss: 0.1257
# Epoch  54 Batch  300/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9247, Loss: 0.1241
# Epoch  54 Batch  400/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.9226, Loss: 0.1432
# Epoch  54 Batch  500/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9279, Loss: 0.1035
# Epoch  54 Batch  600/1077 - Train Accuracy: 0.9330, Validation Accuracy: 0.9474, Loss: 0.1273
# Epoch  54 Batch  700/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9329, Loss: 0.1184
# Epoch  54 Batch  800/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9187, Loss: 0.1287
# Epoch  54 Batch  900/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9229, Loss: 0.1366
# Epoch  54 Batch 1000/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.9350, Loss: 0.1176
# Epoch  55 Batch  100/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9279, Loss: 0.1223
# Epoch  55 Batch  200/1077 - Train Accuracy: 0.9336, Validation Accuracy: 0.9130, Loss: 0.1398
# Epoch  55 Batch  300/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9300, Loss: 0.1143
# Epoch  55 Batch  400/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9098, Loss: 0.1331
# Epoch  55 Batch  500/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.9219, Loss: 0.1123
# Epoch  55 Batch  600/1077 - Train Accuracy: 0.9271, Validation Accuracy: 0.9386, Loss: 0.1233
# Epoch  55 Batch  700/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9336, Loss: 0.1160
# Epoch  55 Batch  800/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9109, Loss: 0.1180
# Epoch  55 Batch  900/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9290, Loss: 0.1376
# Epoch  55 Batch 1000/1077 - Train Accuracy: 0.9319, Validation Accuracy: 0.9134, Loss: 0.1234
# Epoch  56 Batch  100/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9187, Loss: 0.1207
# Epoch  56 Batch  200/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9137, Loss: 0.1128
# Epoch  56 Batch  300/1077 - Train Accuracy: 0.9642, Validation Accuracy: 0.9265, Loss: 0.1136
# Epoch  56 Batch  400/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9318, Loss: 0.1436
# Epoch  56 Batch  500/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9293, Loss: 0.1097
# Epoch  56 Batch  600/1077 - Train Accuracy: 0.9278, Validation Accuracy: 0.9336, Loss: 0.1233
# Epoch  56 Batch  700/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9389, Loss: 0.1137
# Epoch  56 Batch  800/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9297, Loss: 0.1131
# Epoch  56 Batch  900/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9414, Loss: 0.1216
# Epoch  56 Batch 1000/1077 - Train Accuracy: 0.9263, Validation Accuracy: 0.9268, Loss: 0.1254
# Epoch  57 Batch  100/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9418, Loss: 0.1200
# Epoch  57 Batch  200/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.9354, Loss: 0.1335
# Epoch  57 Batch  300/1077 - Train Accuracy: 0.9560, Validation Accuracy: 0.9471, Loss: 0.1133
# Epoch  57 Batch  400/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.9315, Loss: 0.1372
# Epoch  57 Batch  500/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9474, Loss: 0.0994
# Epoch  57 Batch  600/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9325, Loss: 0.1247
# Epoch  57 Batch  700/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9336, Loss: 0.1107
# Epoch  57 Batch  800/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9148, Loss: 0.1117
# Epoch  57 Batch  900/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.9183, Loss: 0.1345
# Epoch  57 Batch 1000/1077 - Train Accuracy: 0.9200, Validation Accuracy: 0.9283, Loss: 0.1105
# Epoch  58 Batch  100/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9357, Loss: 0.1103
# Epoch  58 Batch  200/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9393, Loss: 0.1187
# Epoch  58 Batch  300/1077 - Train Accuracy: 0.9581, Validation Accuracy: 0.9286, Loss: 0.1229
# Epoch  58 Batch  400/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9407, Loss: 0.1391
# Epoch  58 Batch  500/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9375, Loss: 0.1091
# Epoch  58 Batch  600/1077 - Train Accuracy: 0.9397, Validation Accuracy: 0.9446, Loss: 0.1135
# Epoch  58 Batch  700/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9439, Loss: 0.1152
# Epoch  58 Batch  800/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9276, Loss: 0.1120
# Epoch  58 Batch  900/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9297, Loss: 0.1328
# Epoch  58 Batch 1000/1077 - Train Accuracy: 0.9208, Validation Accuracy: 0.9308, Loss: 0.1017
# Epoch  59 Batch  100/1077 - Train Accuracy: 0.9316, Validation Accuracy: 0.9336, Loss: 0.1130
# Epoch  59 Batch  200/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9371, Loss: 0.1187
# Epoch  59 Batch  300/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9268, Loss: 0.1061
# Epoch  59 Batch  400/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9517, Loss: 0.1337
# Epoch  59 Batch  500/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9339, Loss: 0.1101
# Epoch  59 Batch  600/1077 - Train Accuracy: 0.9185, Validation Accuracy: 0.9375, Loss: 0.1016
# Epoch  59 Batch  700/1077 - Train Accuracy: 0.9672, Validation Accuracy: 0.9396, Loss: 0.1000
# Epoch  59 Batch  800/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9354, Loss: 0.1092
# Epoch  59 Batch  900/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9421, Loss: 0.1202
# Epoch  59 Batch 1000/1077 - Train Accuracy: 0.9208, Validation Accuracy: 0.9329, Loss: 0.1160
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    in_lower = sentence.lower()
    word_ids = []
    for word in in_lower.split():
        if word in vocab_to_int:
            word_ids.append(vocab_to_int[word])
        else:
            word_ids.append(vocab_to_int['<UNK>'])
    return word_ids


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [94, 175, 90, 150, 165, 72, 82]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [94, 51, 140, 113, 140, 95, 72, 222, 1]
#   French Words: pas paris les petite les aux pamplemousse . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
